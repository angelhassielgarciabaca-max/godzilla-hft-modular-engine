# %%
# config.py
WATCHLIST = ["btc", "eth"]
CAPITAL_TOTAL = 100000
PORCENTAJE_RIESGO = 0.01  # 1% por operación
STOP_LOSS_PCT = 0.02      # 2% de protección
CVD_UMBRAL_SALIDA = 0     # Salida por debilidad de volumen

# Credenciales Alpaca
ALPACA_CONFIG = {
    "key_id": "PKZ2O6CG3TJACUR7YBBDPJXNDN",
    "secret_key": "DcFZ293dVqkWhzvNa7uGx36qk2szeH6iauhLta4sdYGt",
    "base_url": "https://paper-api.alpaca.markets"
}
